# %% [markdown]
# # Housing Prices Project (module 70)

# %% [markdown]
# ### task1
# - classification task (predicting whether a house is expensive or not)
# - and later move on to the regression task (predicting the exact price).
#
# ### task2
# - Create a Pipeline with your transformers and your model.
# -  Use GridSearchCV to find the best parameters for your model

# %% [markdown]
# ### task3
# Implement One-Hot encoding in your modelling pipeline.
#
# Evaluate your model. Have you improved the performance compared to the last iteration?
#
# As part of your task when completing an iteration,
# - check the performance of the model,
# - tweak as many aspects as you can from the whole pipeline,  (
# Optimieren Sie so viele Aspekte wie möglich aus der gesamten Pipeline)9
# - explore the predictions that the model outputs in relation to the features you have, and
# - gain information that will be useful for future iterations
#
# **Bonus**
# -  Implement Ordinal encoding in your modelling pipeline.
# -  � Evaluate your model. Have you improved the performance compared to the last iteration?.

# %% [markdown]
# ### task4
# gain a basic intuitive understanding of each model, so that you can answer these questions:
# -   Which hyperparameters should I tun
# -    By increasing/decreasing that particular hyperparameter, am I making the algorithm more or less prone to overfitting/underfitti
# - research each algorithm and check the parameters in the Scikit-Learn documentation
#
# housing: Adapt your preprocessing pipeline to the new features, and train as many models as you can, keeping track of their performances.ng?

# %% [markdown]
# ## about Housing
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
#        RP	Residential Low Density Park
#        RM	Residential Medium Density
#
# LotFrontage: Linear feet of street connected to property
#
# LotArea: Lot size in square feet
#
# Street: Type of road access to property
#
#        Grvl	Gravel
#        Pave	Paved
#
# Alley: Type of alley access to property
#
#        Grvl	Gravel
#        Pave	Paved
#        NA 	No alley access
#
# LotShape: General shape of property
#
#        Reg	Regular
#        IR1	Slightly irregular
#        IR2	Moderately Irregular
#        IR3	Irregular
#
# LandContour: Flatness of the property
#
#        Lvl	Near Flat/Level
#        Bnk	Banked - Quick and significant rise from street grade to building
#        HLS	Hillside - Significant slope from side to side
#        Low	Depression
#
# Utilities: Type of utilities available
#
#        AllPub	All public Utilities (E,G,W,& S)
#        NoSewr	Electricity, Gas, and Water (Septic Tank)
#        NoSeWa	Electricity and Gas Only
#        ELO	Electricity only
#
# LotConfig: Lot configuration
#
#        Inside	Inside lot
#        Corner	Corner lot
#        CulDSac	Cul-de-sac
#        FR2	Frontage on 2 sides of property
#        FR3	Frontage on 3 sides of property
#
# LandSlope: Slope of property
#
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
#
# Neighborhood: Physical locations within Ames city limits
#
#        Blmngtn	Bloomington Heights
#        Blueste	Bluestem
#        BrDale	Briardale
#        BrkSide	Brookside
#        ClearCr	Clear Creek
#        CollgCr	College Creek
#        Crawfor	Crawford
#        Edwards	Edwards
#        Gilbert	Gilbert
#        IDOTRR	Iowa DOT and Rail Road
#        MeadowV	Meadow Village
#        Mitchel	Mitchell
#        Names	North Ames
#        NoRidge	Northridge
#        NPkVill	Northpark Villa
#        NridgHt	Northridge Heights
#        NWAmes	Northwest Ames
#        OldTown	Old Town
#        SWISU	South & West of Iowa State University
#        Sawyer	Sawyer
#        SawyerW	Sawyer West
#        Somerst	Somerset
#        StoneBr	Stone Brook
#        Timber	Timberland
#        Veenker	Veenker
#
# Condition1: Proximity to various conditions
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# Condition2: Proximity to various conditions (if more than one is present)
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# BldgType: Type of dwelling
#
#        1Fam	Single-family Detached
#        2FmCon	Two-family Conversion; originally built as one-family dwelling
#        Duplx	Duplex
#        TwnhsE	Townhouse End Unit
#        TwnhsI	Townhouse Inside Unit
#
# HouseStyle: Style of dwelling
#
#        1Story	One story
#        1.5Fin	One and one-half story: 2nd level finished
#        1.5Unf	One and one-half story: 2nd level unfinished
#        2Story	Two story
#        2.5Fin	Two and one-half story: 2nd level finished
#        2.5Unf	Two and one-half story: 2nd level unfinished
#        SFoyer	Split Foyer
#        SLvl	Split Level
#
# OverallQual: Rates the overall material and finish of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# OverallCond: Rates the overall condition of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# YearBuilt: Original construction date
#
# YearRemodAdd: Remodel date (same as construction date if no remodeling or additions)
#
# RoofStyle: Type of roof
#
#        Flat	Flat
#        Gable	Gable
#        Gambrel	Gabrel (Barn)
#        Hip	Hip
#        Mansard	Mansard
#        Shed	Shed
#
# RoofMatl: Roof material
#
#        ClyTile	Clay or Tile
#        CompShg	Standard (Composite) Shingle
#        Membran	Membrane
#        Metal	Metal
#        Roll	Roll
#        Tar&Grv	Gravel & Tar
#        WdShake	Wood Shakes
#        WdShngl	Wood Shingles
#
# Exterior1st: Exterior covering on house
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# Exterior2nd: Exterior covering on house (if more than one material)
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# MasVnrType: Masonry veneer type
#
#        BrkCmn	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        None	None
#        Stone	Stone
#
# MasVnrArea: Masonry veneer area in square feet
#
# ExterQual: Evaluates the quality of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# ExterCond: Evaluates the present condition of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# Foundation: Type of foundation
#
#        BrkTil	Brick & Tile
#        CBlock	Cinder Block
#        PConc	Poured Contrete
#        Slab	Slab
#        Stone	Stone
#        Wood	Wood
#
# BsmtQual: Evaluates the height of the basement
#
#        Ex	Excellent (100+ inches)
#        Gd	Good (90-99 inches)
#        TA	Typical (80-89 inches)
#        Fa	Fair (70-79 inches)
#        Po	Poor (<70 inches
#        NA	No Basement
#
# BsmtCond: Evaluates the general condition of the basement
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical - slight dampness allowed
#        Fa	Fair - dampness or some cracking or settling
#        Po	Poor - Severe cracking, settling, or wetness
#        NA	No Basement
#
# BsmtExposure: Refers to walkout or garden level walls
#
#        Gd	Good Exposure
#        Av	Average Exposure (split levels or foyers typically score average or above)
#        Mn	Mimimum Exposure
#        No	No Exposure
#        NA	No Basement
#
# BsmtFinType1: Rating of basement finished area
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF1: Type 1 finished square feet
#
# BsmtFinType2: Rating of basement finished area (if multiple types)
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF2: Type 2 finished square feet
#
# BsmtUnfSF: Unfinished square feet of basement area
#
# TotalBsmtSF: Total square feet of basement area
#
# Heating: Type of heating
#
#        Floor	Floor Furnace
#        GasA	Gas forced warm air furnace
#        GasW	Gas hot water or steam heat
#        Grav	Gravity furnace
#        OthW	Hot water or steam heat other than gas
#        Wall	Wall furnace
#
# HeatingQC: Heating quality and condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# CentralAir: Central air conditioning
#
#        N	No
#        Y	Yes
#
# Electrical: Electrical system
#
#        SBrkr	Standard Circuit Breakers & Romex
#        FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)
#        FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
#        FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
#        Mix	Mixed
#
# 1stFlrSF: First Floor square feet
#
# 2ndFlrSF: Second floor square feet
#
# LowQualFinSF: Low quality finished square feet (all floors)
#
# GrLivArea: Above grade (ground) living area square feet
#
# BsmtFullBath: Basement full bathrooms
#
# BsmtHalfBath: Basement half bathrooms
#
# FullBath: Full bathrooms above grade
#
# HalfBath: Half baths above grade
#
# BedroomAbvGr: Bedrooms above grade (does NOT include basement bedrooms)
#
# KitchenAbvGr: Kitchens above grade
#
# KitchenQual: Kitchen quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
#
# Functional: Home functionality (Assume typical unless deductions are warranted)
#
#        Typ	Typical Functionality
#        Min1	Minor Deductions 1
#        Min2	Minor Deductions 2
#        Mod	Moderate Deductions
#        Maj1	Major Deductions 1
#        Maj2	Major Deductions 2
#        Sev	Severely Damaged
#        Sal	Salvage only
#
# Fireplaces: Number of fireplaces
#
# FireplaceQu: Fireplace quality
#
#        Ex	Excellent - Exceptional Masonry Fireplace
#        Gd	Good - Masonry Fireplace in main level
#        TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#        Fa	Fair - Prefabricated Fireplace in basement
#        Po	Poor - Ben Franklin Stove
#        NA	No Fireplace
#
# GarageType: Garage location
#
#        2Types	More than one type of garage
#        Attchd	Attached to home
#        Basment	Basement Garage
#        BuiltIn	Built-In (Garage part of house - typically has room above garage)
#        CarPort	Car Port
#        Detchd	Detached from home
#        NA	No Garage
#
# GarageYrBlt: Year garage was built
#
# GarageFinish: Interior finish of the garage
#
#        Fin	Finished
#        RFn	Rough Finished
#        Unf	Unfinished
#        NA	No Garage
#
# GarageCars: Size of garage in car capacity
#
# GarageArea: Size of garage in square feet
#
# GarageQual: Garage quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# GarageCond: Garage condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# PavedDrive: Paved driveway
#
#        Y	Paved
#        P	Partial Pavement
#        N	Dirt/Gravel
#
# WoodDeckSF: Wood deck area in square feet
#
# OpenPorchSF: Open porch area in square feet
#
# EnclosedPorch: Enclosed porch area in square feet
#
# 3SsnPorch: Three season porch area in square feet
#
# ScreenPorch: Screen porch area in square feet
#
# PoolArea: Pool area in square feet
#
# PoolQC: Pool quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        NA	No Pool
#
# Fence: Fence quality
#
#        GdPrv	Good Privacy
#        MnPrv	Minimum Privacy
#        GdWo	Good Wood
#        MnWw	Minimum Wood/Wire
#        NA	No Fence
#
# MiscFeature: Miscellaneous feature not covered in other categories
#
#        Elev	Elevator
#        Gar2	2nd Garage (if not described in garage section)
#        Othr	Other
#        Shed	Shed (over 100 SF)
#        TenC	Tennis Court
#        NA	None
#
# MiscVal: $Value of miscellaneous feature
#
# MoSold: Month Sold (MM)
#
# YrSold: Year Sold (YYYY)
#
# SaleType: Type of sale
#
#        WD 	Warranty Deed - Conventional
#        CWD	Warranty Deed - Cash
#        VWD	Warranty Deed - VA Loan
#        New	Home just constructed and sold
#        COD	Court Officer Deed/Estate
#        Con	Contract 15% Down payment regular terms
#        ConLw	Contract Low Down payment and low interest
#        ConLI	Contract Low Interest
#        ConLD	Contract Low Down
#        Oth	Other
#
# SaleCondition: Condition of sale
#
#        Normal	Normal Sale
#        Abnorml	Abnormal Sale -  trade, foreclosure, short sale
#        AdjLand	Adjoining Land Purchase
#        Alloca	Allocation - two linked properties with separate deeds, typically condo with a garage unit
#        Family	Sale between family members
#        Partial	Home was not completed when last assessed (associated with New Homes)

# %% [markdown]
# **rem:**
# Unit of measurement is feet

# %% [markdown]
# # Imports and Settings

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score, f1_score, cohen_kappa_score, precision_score, recall_score, roc_auc_score  #, make_scorer

# %%
# import data
data = pd.read_table("data/housing_iteration_5_classification.csv", sep=",")

# %% [markdown]
# # EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LotArea        1460 non-null   int64
#  1   LotFrontage    1201 non-null   float64
#  2   TotalBsmtSF    1460 non-null   int64
#  3   BedroomAbvGr   1460 non-null   int64
#  4   Fireplaces     1460 non-null   int64
#  5   PoolArea       1460 non-null   int64
#  6   GarageCars     1460 non-null   int64
#  7   WoodDeckSF     1460 non-null   int64
#  8   ScreenPorch    1460 non-null   int64
#  9   Expensive      1460 non-null   int64
#  10  MSZoning       1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Heating        1460 non-null   object
#  13  Street         1460 non-null   object
#  14  CentralAir     1460 non-null   object
#  15  Foundation     1460 non-null   object
#  16  ExterQual      1460 non-null   object
#  17  ExterCond      1460 non-null   object
#  18  BsmtQual       1423 non-null   object
#  19  BsmtCond       1423 non-null   object
#  20  BsmtExposure   1422 non-null   object
#  21  BsmtFinType1   1423 non-null   object
#  22  KitchenQual    1460 non-null   object
#  23  FireplaceQu    770 non-null    object
#  24  MSSubClass     1460 non-null   int64
#  25  OverallQual    1460 non-null   int64
#  26  OverallCond    1460 non-null   int64
#  27  YearBuilt      1460 non-null   int64
#  28  YearRemodAdd   1460 non-null   int64
#  29  MasVnrArea     1452 non-null   float64
#  30  BsmtFinSF1     1460 non-null   int64
#  31  BsmtFinSF2     1460 non-null   int64
#  32  BsmtUnfSF      1460 non-null   int64
#  33  1stFlrSF       1460 non-null   int64
#  34  2ndFlrSF       1460 non-null   int64
#  35  LowQualFinSF   1460 non-null   int64
#  36  GrLivArea      1460 non-null   int64
#  37  BsmtFullBath   1460 non-null   int64
#  38  BsmtHalfBath   1460 non-null   int64
#  39  FullBath       1460 non-null   int64
#  40  HalfBath       1460 non-null   int64
#  41  KitchenAbvGr   1460 non-null   int64
#  42  TotRmsAbvGrd   1460 non-null   int64
#  43  GarageYrBlt    1379 non-null   float64
#  44  GarageArea     1460 non-null   int64
#  45  OpenPorchSF    1460 non-null   int64
#  46  EnclosedPorch  1460 non-null   int64
#  47  3SsnPorch      1460 non-null   int64
#  48  MiscVal        1460 non-null   int64
#  49  MoSold         1460 non-null   int64
#  50  YrSold         1460 non-null   int64
#  51  Id             1460 non-null   int64
#  52  Alley          91 non-null     object
#  53  LotShape       1460 non-null   object
#  54  LandContour    1460 non-null   object
#  55  Utilities      1460 non-null   object
#  56  LotConfig      1460 non-null   object
#  57  LandSlope      1460 non-null   object
#  58  Neighborhood   1460 non-null   object
#  59  Condition2     1460 non-null   object
#  60  BldgType       1460 non-null   object
#  61  HouseStyle     1460 non-null   object
#  62  RoofStyle      1460 non-null   object
#  63  RoofMatl       1460 non-null   object
#  64  Exterior1st    1460 non-null   object
#  65  Exterior2nd    1460 non-null   object
#  66  MasVnrType     588 non-null    object
#  67  BsmtFinType2   1422 non-null   object
#  68  HeatingQC      1460 non-null   object
#  69  Electrical     1459 non-null   object
#  70  Functional     1460 non-null   object
#  71  GarageType     1379 non-null   object
#  72  GarageFinish   1379 non-null   object
#  73  GarageQual     1379 non-null   object
#  74  GarageCond     1379 non-null   object
#  75  PavedDrive     1460 non-null   object
#  76  PoolQC         7 non-null      object
#  77  Fence          281 non-null    object
#  78  MiscFeature    54 non-null     object
#  79  SaleType       1460 non-null   object
#  80  SaleCondition  1460 non-null   object
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
data.head(3)
# Out:
#    LotArea  LotFrontage  TotalBsmtSF  BedroomAbvGr  Fireplaces  PoolArea  \
# 0     8450         65.0          856             3           0         0
# 1     9600         80.0         1262             3           1         0
# 2    11250         68.0          920             3           1         0
#
#    GarageCars  WoodDeckSF  ScreenPorch  Expensive  ... GarageType  \
# 0           2           0            0          0  ...     Attchd
# 1           2         298            0          0  ...     Attchd
# 2           2           0            0          0  ...     Attchd
#
#   GarageFinish GarageQual GarageCond PavedDrive PoolQC Fence MiscFeature  \
# 0          RFn         TA         TA          Y    NaN   NaN         NaN
# 1          RFn         TA         TA          Y    NaN   NaN         NaN
# 2          RFn         TA         TA          Y    NaN   NaN         NaN
#
#   SaleType SaleCondition
# 0       WD        Normal
# 1       WD        Normal
# 2       WD        Normal
#
# [3 rows x 81 columns]

# %%
# value_counts (and percentage) for categorical freatures

cat_features = data.select_dtypes(include="object").columns

value_counts=[]
for i in cat_features:
    counts = data[i].value_counts()
    value_counts.append(counts)

# # percentage dictionary
# value_perc = {}
# for i in cat_features:
#     counts = data[i].value_counts()
#     perc = data[i].value_counts(normalize=True) * 100
#     value_counts[i] = {"counts": counts, "percent": perc}

value_counts
# Out:
# [MSZoning
#  RL         1151
#  RM          218
#  FV           65
#  RH           16
#  C (all)      10
#  Name: count, dtype: int64,
#  Condition1
#  Norm      1260
#  Feedr       81
#  Artery      48
#  RRAn        26
#  PosN        19
#  RRAe        11
#  PosA         8
#  RRNn         5
#  RRNe         2
#  Name: count, dtype: int64,
#  Heating
#  GasA     1428
#  GasW       18
#  Grav        7
#  Wall        4
#  OthW        2
#  Floor       1
#  Name: count, dtype: int64,
#  Street
#  Pave    1454
#  Grvl       6
#  Name: count, dtype: int64,
#  CentralAir
#  Y    1365
#  N      95
#  Name: count, dtype: int64,
#  Foundation
#  PConc     647
#  CBlock    634
#  BrkTil    146
#  Slab       24
#  Stone       6
#  Wood        3
#  Name: count, dtype: int64,
#  ExterQual
#  TA    906
#  Gd    488
#  Ex     52
#  Fa     14
#  Name: count, dtype: int64,
#  ExterCond
#  TA    1282
#  Gd     146
#  Fa      28
#  Ex       3
#  Po       1
#  Name: count, dtype: int64,
#  BsmtQual
#  TA    649
#  Gd    618
#  Ex    121
#  Fa     35
#  Name: count, dtype: int64,
#  BsmtCond
#  TA    1311
#  Gd      65
#  Fa      45
#  Po       2
#  Name: count, dtype: int64,
#  BsmtExposure
#  No    953
#  Av    221
#  Gd    134
#  Mn    114
#  Name: count, dtype: int64,
#  BsmtFinType1
#  Unf    430
#  GLQ    418
#  ALQ    220
#  BLQ    148
#  Rec    133
#  LwQ     74
#  Name: count, dtype: int64,
#  KitchenQual
#  TA    735
#  Gd    586
#  Ex    100
#  Fa     39
#  Name: count, dtype: int64,
#  FireplaceQu
#  Gd    380
#  TA    313
#  Fa     33
#  Ex     24
#  Po     20
#  Name: count, dtype: int64,
#  Alley
#  Grvl    50
#  Pave    41
#  Name: count, dtype: int64,
#  LotShape
#  Reg    925
#  IR1    484
#  IR2     41
#  IR3     10
#  Name: count, dtype: int64,
#  LandContour
#  Lvl    1311
#  Bnk      63
#  HLS      50
#  Low      36
#  Name: count, dtype: int64,
#  Utilities
#  AllPub    1459
#  NoSeWa       1
#  Name: count, dtype: int64,
#  LotConfig
#  Inside     1052
#  Corner      263
#  CulDSac      94
#  FR2          47
#  FR3           4
#  Name: count, dtype: int64,
#  LandSlope
#  Gtl    1382
#  Mod      65
#  Sev      13
#  Name: count, dtype: int64,
#  Neighborhood
#  NAmes      225
#  CollgCr    150
#  OldTown    113
#  Edwards    100
#  Somerst     86
#  Gilbert     79
#  NridgHt     77
#  Sawyer      74
#  NWAmes      73
#  SawyerW     59
#  BrkSide     58
#  Crawfor     51
#  Mitchel     49
#  NoRidge     41
#  Timber      38
#  IDOTRR      37
#  ClearCr     28
#  StoneBr     25
#  SWISU       25
#  MeadowV     17
#  Blmngtn     17
#  BrDale      16
#  Veenker     11
#  NPkVill      9
#  Blueste      2
#  Name: count, dtype: int64,
#  Condition2
#  Norm      1445
#  Feedr        6
#  Artery       2
#  RRNn         2
#  PosN         2
#  PosA         1
#  RRAn         1
#  RRAe         1
#  Name: count, dtype: int64,
#  BldgType
#  1Fam      1220
#  TwnhsE     114
#  Duplex      52
#  Twnhs       43
#  2fmCon      31
#  Name: count, dtype: int64,
#  HouseStyle
#  1Story    726
#  2Story    445
#  1.5Fin    154
#  SLvl       65
#  SFoyer     37
#  1.5Unf     14
#  2.5Unf     11
#  2.5Fin      8
#  Name: count, dtype: int64,
#  RoofStyle
#  Gable      1141
#  Hip         286
#  Flat         13
#  Gambrel      11
#  Mansard       7
#  Shed          2
#  Name: count, dtype: int64,
#  RoofMatl
#  CompShg    1434
#  Tar&Grv      11
#  WdShngl       6
#  WdShake       5
#  Metal         1
#  Membran       1
#  Roll          1
#  ClyTile       1
#  Name: count, dtype: int64,
#  Exterior1st
#  VinylSd    515
#  HdBoard    222
#  MetalSd    220
#  Wd Sdng    206
#  Plywood    108
#  CemntBd     61
#  BrkFace     50
#  WdShing     26
#  Stucco      25
#  AsbShng     20
#  BrkComm      2
#  Stone        2
#  AsphShn      1
#  ImStucc      1
#  CBlock       1
#  Name: count, dtype: int64,
#  Exterior2nd
#  VinylSd    504
#  MetalSd    214
#  HdBoard    207
#  Wd Sdng    197
#  Plywood    142
#  CmentBd     60
#  Wd Shng     38
#  Stucco      26
#  BrkFace     25
#  AsbShng     20
#  ImStucc     10
#  Brk Cmn      7
#  Stone        5
#  AsphShn      3
#  Other        1
#  CBlock       1
#  Name: count, dtype: int64,
#  MasVnrType
#  BrkFace    445
#  Stone      128
#  BrkCmn      15
#  Name: count, dtype: int64,
#  BsmtFinType2
#  Unf    1256
#  Rec      54
#  LwQ      46
#  BLQ      33
#  ALQ      19
#  GLQ      14
#  Name: count, dtype: int64,
#  HeatingQC
#  Ex    741
#  TA    428
#  Gd    241
#  Fa     49
#  Po      1
#  Name: count, dtype: int64,
#  Electrical
#  SBrkr    1334
#  FuseA      94
#  FuseF      27
#  FuseP       3
#  Mix         1
#  Name: count, dtype: int64,
#  Functional
#  Typ     1360
#  Min2      34
#  Min1      31
#  Mod       15
#  Maj1      14
#  Maj2       5
#  Sev        1
#  Name: count, dtype: int64,
#  GarageType
#  Attchd     870
#  Detchd     387
#  BuiltIn     88
#  Basment     19
#  CarPort      9
#  2Types       6
#  Name: count, dtype: int64,
#  GarageFinish
#  Unf    605
#  RFn    422
#  Fin    352
#  Name: count, dtype: int64,
#  GarageQual
#  TA    1311
#  Fa      48
#  Gd      14
#  Ex       3
#  Po       3
#  Name: count, dtype: int64,
#  GarageCond
#  TA    1326
#  Fa      35
#  Gd       9
#  Po       7
#  Ex       2
#  Name: count, dtype: int64,
#  PavedDrive
#  Y    1340
#  N      90
#  P      30
#  Name: count, dtype: int64,
#  PoolQC
#  Gd    3
#  Ex    2
#  Fa    2
#  Name: count, dtype: int64,
#  Fence
#  MnPrv    157
#  GdPrv     59
#  GdWo      54
#  MnWw      11
#  Name: count, dtype: int64,
#  MiscFeature
#  Shed    49
#  Gar2     2
#  Othr     2
#  TenC     1
#  Name: count, dtype: int64,
#  SaleType
#  WD       1267
#  New       122
#  COD        43
#  ConLD       9
#  ConLI       5
#  ConLw       5
#  CWD         4
#  Oth         3
#  Con         2
#  Name: count, dtype: int64,
#  SaleCondition
#  Normal     1198
#  Partial     125
#  Abnorml     101
#  Family       20
#  Alloca       12
#  AdjLand       4
#  Name: count, dtype: int64]

# %%
# check for null values
nullvalues = data.isnull().sum()
nullvalues.sort_values(ascending=False).head(20)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageFinish      81
# GarageType        81
# GarageYrBlt       81
# GarageQual        81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# MiscVal            0
# dtype: int64

# %% [markdown]
# # >>> Data Prep (Splitting X & y, train & test)

# %%
# check value balance of y
y = "Expensive"  # -----------------> INPUT of intended y <-----------------------------------< INPUT y
# balance = data[y].value_counts()
# balance
percentage = data[y].value_counts(normalize=True) * 100
percentage
# Out:
# Expensive
# 0    85.136986
# 1    14.863014
# Name: proportion, dtype: float64

# %%
# delete data with NaNs in y feature
data.dropna(subset=[y], inplace=True)

# define y (and X)
y = data.pop(y)
X = data

# feature engineering
# X.loc[:, "Cabin"] = X.Cabin.str[0]  # extracting only the first character of each string
# X.loc[X.loc[:, "Heating"] == "Floor", "Heating"] = "NA"
X['Street'] = X['Street'].replace({'Pave': 1, 'Grvl': 0})
X['CentralAir'] = X['CentralAir'].replace({'Y': 1, 'N': 0})

# ---> general INPUTS and for data split <--------------------------------------------------< INPUTS split
seed = 123        # random_state
split = 0.2       # split portion for test_dataset

# split data to train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=split, random_state=seed)

# %%
# INPUTS for cross validation and quality check/score <---------------------------------------< INPUTS folds & model_score
cv_folds = 5
score_metric = "accuracy"  # ["make_scorer", "accuracy", "precision", "recall", "f1", "roc_auc"]
model_scores_dict = {}

# %% [markdown]
# # Preprocessor (upper reach)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer

# %%
# define numerical and categorial branch
num_features = data.select_dtypes(include="number").columns
cat_features = data.select_dtypes(include="object").columns

# define transformers for each branch
num_branch = make_pipeline(SimpleImputer(), StandardScaler())
cat_branch = make_pipeline(SimpleImputer(strategy="constant", fill_value="NA"), OneHotEncoder(handle_unknown="ignore", sparse_output=False)).set_output(transform='pandas')

# create branches for preprocessor
preprocessor = make_column_transformer(
                    (num_branch, num_features),
                    (cat_branch, cat_features))

# %% [markdown]
# # Estimators (downstream)

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

pipe = make_pipeline(preprocessor, DecisionTreeClassifier())
grid = {
    # 'simpleimputer__strategy':['mean', 'median', 'most_frequent'],
    'columntransformer__pipeline-1__simpleimputer__strategy':['mean'],     # 1 = num_branch
    # 'standardscaler__with_mean':[True,False],
    # 'standardscaler__with_std':[True,False],
    # 'decisiontreeclassifier__max_depth': range(5, 8, 2),
    # 'decisiontreeclassifier__min_samples_leaf': range(5, 11, 3),
    # 'decisiontreeclassifier__min_samples_split': range(5, 30, 5),
    # 'decisiontreeclassifier__criterion':['gini', 'entropy']
    }

# cross validation
dtree_model = GridSearchCV(pipe, grid, cv=cv_folds, refit=True, scoring=score_metric, verbose=1)
dtree_model.fit(X_train, y_train)

# scores dictionary
model_scores_dict = {"dtree" : round(dtree_model.best_score_, 4)}
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits

# %%
dtree_model.best_params_
# Out:
# {'columntransformer__pipeline-1__simpleimputer__strategy': 'mean'}

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import validation_curve
# Define the parameter values for which you want to plot the validation curve
param_range_max_depth = range(3, 8, 2)
param_range_min_samples_leaf = range(5, 15, 3)
param_range_min_samples_split = range(5, 30, 5)
param_range_criterion = ['gini', 'entropy']

# Generate validation curve scores for max_depth
train_scores_max_depth, test_scores_max_depth = validation_curve(
    pipe, X_train, y_train,
    param_name="decisiontreeclassifier__max_depth",
    param_range=param_range_max_depth,
    cv=cv_folds,
    scoring=score_metric,
    n_jobs=-1
)

# Generate validation curve scores for min_samples_leaf
train_scores_min_samples_leaf, test_scores_min_samples_leaf = validation_curve(
    pipe, X_train, y_train,
    param_name="decisiontreeclassifier__min_samples_leaf",
    param_range=param_range_min_samples_leaf,
    cv=cv_folds,
    scoring=score_metric,
    n_jobs=-1
)

# Generate validation curve scores for min_samples_split
train_scores_min_samples_split, test_scores_min_samples_split = validation_curve(
    pipe, X_train, y_train,
    param_name="decisiontreeclassifier__min_samples_split",
    param_range=param_range_min_samples_split,
    cv=cv_folds,
    scoring=score_metric,
    n_jobs=-1
)

# Function to plot a validation curve
def plot_validation_curve(param_range, train_scores, test_scores, param_name, ax):
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)

    ax.set_title(f"Validation Curve ({param_name})")
    ax.set_xlabel(f"{param_name}")
    ax.set_ylabel("Score")
    ax.set_ylim(0.0, 1.1)

    if isinstance(param_range[0], (int, float)):
        ax.set_xticks(param_range)

    ax.plot(param_range, train_scores_mean, label="Training score", color="darkorange", marker='o')
    ax.fill_between(param_range, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.2, color="darkorange")
    ax.plot(param_range, test_scores_mean, label="Cross-validation score", color="navy", marker='o')
    ax.fill_between(param_range, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.2, color="navy")
    ax.legend(loc="best")

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))

# Plot validation curves for max_depth, min_samples_leaf, and min_samples_split
plot_validation_curve(param_range_max_depth, train_scores_max_depth, test_scores_max_depth, "max_depth", axes[0])
plot_validation_curve(param_range_min_samples_leaf, train_scores_min_samples_leaf, test_scores_min_samples_leaf, "min_samples_leaf", axes[1])
plot_validation_curve(param_range_min_samples_split, train_scores_min_samples_split, test_scores_min_samples_split, "min_samples_split", axes[2])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## K-Nearest-Neibhbors

# %%
from sklearn.neighbors import KNeighborsClassifier

pipe = make_pipeline(preprocessor, KNeighborsClassifier())
grid = {
    "columntransformer__pipeline-1__simpleimputer__strategy":["mean"],
    # "kneighborsclassifier__n_neighbors": range(5, 10),            # k Number of neighbors to use
    # "kneighborsclassifier__weights": ["uniform" , "distance"],   # weight points by the inverse of their distance
    # "kneighborsclassifier__p": [1,2]                             # p = 1 uses manhattan_distance (stairs), p=2 uses euclidean_distance (shortest). default=minkowski_distance (a line btw manhatten and eurclidean) is used.
}

# cross validation
knn_model = GridSearchCV(pipe, grid, cv=cv_folds, scoring=score_metric, verbose=1)
knn_model.fit(X_train, y_train)

# scores dictionary
model_scores_dict["knn"] = round(knn_model.best_score_, 4)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits

# %%
knn_model.best_params_
# Out:
# {'columntransformer__pipeline-1__simpleimputer__strategy': 'mean'}

# %%
# Define the parameter values for which you want to plot the validation curve
param_range = range(1, 10)

# Generate validation curve scores
train_scores, test_scores = validation_curve(
    pipe, X_train, y_train,
    param_name="kneighborsclassifier__n_neighbors",
    param_range=param_range,
    cv=cv_folds,
    scoring=score_metric,
    n_jobs=-1
)

# Calculate the mean and standard deviation of the scores for training and test sets
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plot the validation curve
plt.figure(figsize=(10, 6))
plt.title("Validation Curve with KNeighborsClassifier")
plt.xlabel("Number of Neighbors (k)")
plt.ylabel("Score")
plt.ylim(0.0, 1.1)
plt.xticks(param_range)
plt.plot(param_range, train_scores_mean, label="Training score", color="darkorange", marker='o')
plt.fill_between(param_range, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.2, color="darkorange")
plt.plot(param_range, test_scores_mean, label="Cross-validation score", color="navy", marker='o')
plt.fill_between(param_range, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.2, color="navy")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

pipe = make_pipeline(preprocessor, StandardScaler(), LogisticRegression(solver='liblinear'))
grid = {
    "columntransformer__pipeline-1__simpleimputer__strategy":["mean"],
    # 'logisticregression__penalty': ['l1'],                          # ['l1', 'l2', 'elasticnet', 'none'] specifies the norm used in the penalization
    # 'logisticregression__C': [0.001, 0.01, 1, 10, 100],             # [0.001, 0.01, 0.1, 1, 10, 100] Inverse of regularization strength. Smaller values specify stronger regularization.
    # 'logisticregression__solver': ['saga'],                         # ['lbfgs', 'liblinear', 'newton-cg', 'sag', 'saga']  to find the coefficients that minimize the logistic loss function, which one depends on characteristics of dataset, eg: sparse data = 
    # 'logisticregression__max_iter': [3000, 5000]                    # [100, 200, 300] Maximum number of iterations for the solver to converge
}

# cross validation
LogReg_model = GridSearchCV(pipe, grid, cv=cv_folds, scoring=score_metric, verbose=1)
LogReg_model.fit(X_train, y_train)

# scores dictionary
model_scores_dict["LogReg"] = round(LogReg_model.best_score_, 4)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits

# %%
LogReg_model.best_params_
# Out:
# {'columntransformer__pipeline-1__simpleimputer__strategy': 'mean'}

# %%
# Define the parameter values for which you want to plot the validation curve
param_range_C = [0.001, 0.01]
param_range_penalty = ['l1']

# Generate validation curve scores for C
train_scores_C, test_scores_C = validation_curve(
    pipe, X_train, y_train,
    param_name="logisticregression__C",
    param_range=param_range_C,
    cv=cv_folds,
    scoring=score_metric,
    n_jobs=-1
)

# Generate validation curve scores for penalty
train_scores_penalty, test_scores_penalty = validation_curve(
    pipe, X_train, y_train,
    param_name="logisticregression__penalty",
    param_range=param_range_penalty,
    cv=cv_folds,
    scoring=score_metric,
    n_jobs=-1
)

# Function to plot a validation curve
def plot_validation_curve(param_range, train_scores, test_scores, param_name, ax):
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)

    ax.set_title(f"Validation Curve ({param_name})")
    ax.set_xlabel(f"{param_name}")
    ax.set_ylabel("Score")
    ax.set_ylim(0.0, 1.1)

    if isinstance(param_range[0], (int, float)):
        ax.set_xticks(param_range)

    ax.plot(param_range, train_scores_mean, label="Training score", color="darkorange", marker='o')
    ax.fill_between(param_range, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.2, color="darkorange")
    ax.plot(param_range, test_scores_mean, label="Cross-validation score", color="navy", marker='o')
    ax.fill_between(param_range, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.2, color="navy")
    ax.legend(loc="best")

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Plot validation curves for C and penalty
plot_validation_curve(param_range_C, train_scores_C, test_scores_C, "C", axes[0])
plot_validation_curve(param_range_penalty, train_scores_penalty, test_scores_penalty, "penalty", axes[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Support Vector Machine (SVM)

# %%
from sklearn.svm import SVC

pipe = make_pipeline(preprocessor, StandardScaler(), SVC(class_weight="balanced"))
grid = {
    "columntransformer__pipeline-1__simpleimputer__strategy":["mean"],
    'svc__C': [0.1, 1, 5, 10, 20],             # 'svc__C': [0.5, 1, 10, 100, 1000], # C values must be > 0
    'svc__kernel': ['rbf', 'poly'],                    # 'svc__kernel': ['linear', 'rbf', 'poly'],
    'svc__gamma': [0.0001, 0.0002, 0.0005],            # 'svc__gamma': ['scale', 'auto', 0.0001, 0.001, 0.01, 0.1, 1, 10, 100] samll gamma = more generalized decision boundary

# statquest 35min30 on https://www.youtube.com/watch?v=8A7L0GsBiLQ
}

# cross validation
SVC_model = GridSearchCV(pipe, grid, cv=cv_folds, scoring=score_metric, verbose=1)
SVC_model.fit(X_train, y_train)

# scores dictionary
model_scores_dict["SVC"] = round(SVC_model.best_score_, 4)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits

# %%
SVC_model.best_params_
# Out:
# {'columntransformer__pipeline-1__simpleimputer__strategy': 'mean',
#  'svc__C': 10,
#  'svc__gamma': 0.0002,
#  'svc__kernel': 'rbf'}

# %%
# Define the parameter values for which you want to plot the validation curve
param_range_kernel = ['rbf', 'poly']                   # ['linear', 'rbf', 'poly']
param_range_gamma = [0.0001, 0.0002, 0.0005]
param_range_c = [0.1, 1, 5, 10, 20]

# Generate validation curve scores for kernel
train_scores_kernel, test_scores_kernel = validation_curve(
    pipe, X_train, y_train,
    param_name="svc__kernel",
    param_range=param_range_kernel,
    cv=cv_folds,
    scoring=score_metric,
    n_jobs=-1
)

# Generate validation curve scores for gamma
train_scores_gamma, test_scores_gamma = validation_curve(
    pipe, X_train, y_train,
    param_name="svc__gamma",
    param_range=param_range_gamma,
    cv=cv_folds,
    scoring=score_metric,
    n_jobs=-1
)

# Function to plot a validation curve
def plot_validation_curve(param_range, train_scores, test_scores, param_name, ax):
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)

    ax.set_title(f"Validation Curve ({param_name})")
    ax.set_xlabel(f"{param_name}")
    ax.set_ylabel("Score")
    ax.set_ylim(0.0, 1.1)

    ax.set_xticks(np.arange(len(param_range)))
    ax.set_xticklabels(param_range)

    ax.plot(np.arange(len(param_range)), train_scores_mean, label="Training score", color="darkorange", marker='o')
    ax.fill_between(np.arange(len(param_range)), train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.2, color="darkorange")
    ax.plot(np.arange(len(param_range)), test_scores_mean, label="Cross-validation score", color="navy", marker='o')
    ax.fill_between(np.arange(len(param_range)), test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.2, color="navy")
    ax.legend(loc="best")

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Plot validation curves for kernel and gamma
plot_validation_curve(param_range_kernel, train_scores_kernel, test_scores_kernel, "kernel", axes[0])
plot_validation_curve(param_range_gamma, train_scores_gamma, test_scores_gamma, "gamma", axes[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

pipe = make_pipeline(preprocessor, StandardScaler(), RandomForestClassifier())
grid = {
    "columntransformer__pipeline-1__simpleimputer__strategy":["mean"],
    'randomforestclassifier__n_estimators': [25, 27, 30],            # number of trees in the forest
    'randomforestclassifier__max_depth': range(4, 8),                # levels of the trees
    'randomforestclassifier__min_samples_split': [4, 6, 8],           # min obs for a node to be split again
    'randomforestclassifier__min_samples_leaf': range(5, 9, 2)        # min nr of obs for a leafe
}

# cross validation
forest_model = GridSearchCV(pipe, grid, cv=cv_folds, scoring=score_metric, verbose=1)
forest_model.fit(X_train, y_train)

# scores dictionary
model_scores_dict["forest"] = round(forest_model.best_score_, 4)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits

# %%
forest_model.best_params_
# Out:
# {'columntransformer__pipeline-1__simpleimputer__strategy': 'mean',
#  'randomforestclassifier__max_depth': 7,
#  'randomforestclassifier__min_samples_leaf': 5,
#  'randomforestclassifier__min_samples_split': 4,
#  'randomforestclassifier__n_estimators': 27}

# %%
# Define the parameter values for which you want to plot the validation curve
param_range_n_estimators = [25, 27, 30]
param_range_max_depth = range(4, 8)
param_range_min_samples_split = [4,6, 8]
param_range_min_samples_leaf = range(5,9, 2)

# Generate validation curve scores for n_estimators
train_scores_n_estimators, test_scores_n_estimators = validation_curve(
    pipe, X_train, y_train,
    param_name="randomforestclassifier__n_estimators",
    param_range=param_range_n_estimators,
    cv=cv_folds,
    scoring=score_metric,
    n_jobs=-1
)

# Generate validation curve scores for max_depth
train_scores_max_depth, test_scores_max_depth = validation_curve(
    pipe, X_train, y_train,
    param_name="randomforestclassifier__max_depth",
    param_range=param_range_max_depth,
    cv=cv_folds,
    scoring=score_metric,
    n_jobs=-1
)

# Generate validation curve scores for min_samples_split
train_scores_min_samples_split, test_scores_min_samples_split = validation_curve(
    pipe, X_train, y_train,
    param_name="randomforestclassifier__min_samples_split",
    param_range=param_range_min_samples_split,
    cv=cv_folds,
    scoring=score_metric,
    n_jobs=-1
)

# Generate validation curve scores for min_samples_leaf
train_scores_min_samples_leaf, test_scores_min_samples_leaf = validation_curve(
    pipe, X_train, y_train,
    param_name="randomforestclassifier__min_samples_leaf",
    param_range=param_range_min_samples_leaf,
    cv=cv_folds,
    scoring=score_metric,
    n_jobs=-1
)

# Function to plot a validation curve
def plot_validation_curve(param_range, train_scores, test_scores, param_name, ax):
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)

    ax.set_title(f"Validation Curve ({param_name})")
    ax.set_xlabel(f"{param_name}")
    ax.set_ylabel("Score")
    ax.set_ylim(0.0, 1.1)

    if isinstance(param_range[0], (int, float)):
        ax.set_xticks(param_range)

    ax.plot(param_range, train_scores_mean, label="Training score", color="darkorange", marker='o')
    ax.fill_between(param_range, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.2, color="darkorange")
    ax.plot(param_range, test_scores_mean, label="Cross-validation score", color="navy", marker='o')
    ax.fill_between(param_range, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.2, color="navy")
    ax.legend(loc="best")

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 10))

# Plot validation curves for n_estimators, max_depth, min_samples_split, and min_samples_leaf
plot_validation_curve(param_range_n_estimators, train_scores_n_estimators, test_scores_n_estimators, "n_estimators", axes[0, 0])
plot_validation_curve(param_range_max_depth, train_scores_max_depth, test_scores_max_depth, "max_depth", axes[0, 1])
plot_validation_curve(param_range_min_samples_split, train_scores_min_samples_split, test_scores_min_samples_split, "min_samples_split", axes[1, 0])
plot_validation_curve(param_range_min_samples_leaf, train_scores_min_samples_leaf, test_scores_min_samples_leaf, "min_samples_leaf", axes[1, 1])

plt.tight_layout()
plt.show()

# %% [markdown]
# # Quality Check

# %%
dtree_model
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('pipeline-1',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('standardscaler',
#                                                                                           StandardScaler())]),
#                                                                          Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch', 'Street',
#        'CentralAir', 'MSSu...
#        'Exterior2nd', 'MasVnrType', 'BsmtFinType2', 'HeatingQC', 'Electrical',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType',
#        'SaleCondition'],
#       dtype='object'))])),
#                                        ('decisiontreeclassifier',
#                                         DecisionTreeClassifier())]),
#              param_grid={'columntransformer__pipeline-1__simpleimputer__strategy': ['mean']},
#              scoring='accuracy', verbose=1)

# %%
# best model_scores from cross validation
model_scores_dict
# Out:
# {'dtree': 0.9169,
#  'knn': 0.9204,
#  'LogReg': 0.9264,
#  'SVC': 0.9426,
#  'forest': 0.9409}

# %% [markdown]
# ## Train-Test-Accuracy

# %%
from sklearn.metrics import accuracy_score, f1_score, cohen_kappa_score , precision_score, recall_score, roc_auc_score #, make_scorer

models = [dtree_model, knn_model, LogReg_model, SVC_model, forest_model]
model_names = ["dtree_model", "knn_model", "LogReg_model", "SVC_model", "forest_model"]

eval_dict = {}
for m, n in zip(models, model_names):
    
    # accuracy
    y_train_pred = m.predict(X_train)
    train_acc = accuracy_score(y_train, y_train_pred)
    y_test_pred = m.predict(X_test)
    test_acc = accuracy_score(y_test, y_test_pred)
    acc_delta = train_acc - test_acc

    # Storing results in eval_dict
    eval_dict[n] = {
        "Training Accuracy": train_acc,
        "Testing Accuracy": test_acc,
        "Accuracy_Delta": acc_delta,
        }
    
eval_df = pd.DataFrame(eval_dict)
eval_df
# Out:
#                    dtree_model  knn_model  LogReg_model  SVC_model  \
# Training Accuracy     1.000000   0.946062      0.994007   0.962329
# Testing Accuracy      0.928082   0.952055      0.921233   0.938356
# Accuracy_Delta        0.071918  -0.005993      0.072774   0.023973
#
#                    forest_model
# Training Accuracy      0.959760
# Testing Accuracy       0.945205
# Accuracy_Delta         0.014555

# %%
dtree_model.best_params_
# Out:
# {'columntransformer__pipeline-1__simpleimputer__strategy': 'mean'}

# %%
knn_model.best_params_
# Out:
# {'columntransformer__pipeline-1__simpleimputer__strategy': 'mean'}

# %%
LogReg_model.best_params_
# Out:
# {'columntransformer__pipeline-1__simpleimputer__strategy': 'mean'}

# %%
SVC_model.best_params_
# Out:
# {'columntransformer__pipeline-1__simpleimputer__strategy': 'mean',
#  'svc__C': 10,
#  'svc__gamma': 0.0002,
#  'svc__kernel': 'rbf'}

# %%
forest_model.best_params_
# Out:
# {'columntransformer__pipeline-1__simpleimputer__strategy': 'mean',
#  'randomforestclassifier__max_depth': 7,
#  'randomforestclassifier__min_samples_leaf': 5,
#  'randomforestclassifier__min_samples_split': 4,
#  'randomforestclassifier__n_estimators': 27}

# %%
# dtree_model.get_params()

# %%
# dtree_model.cv_results_

# %% [markdown]
# ## Features

# %%
dtree_model.n_features_in_  # Number of features seen during fit.
# Out:
# 80

# %%
dtree_model.feature_names_in_  # Names of features seen during fit. (Only defined if best_estimator_ is defined)
# Out:
# array(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr',
#        'Fireplaces', 'PoolArea', 'GarageCars', 'WoodDeckSF',
#        'ScreenPorch', 'MSZoning', 'Condition1', 'Heating', 'Street',
#        'CentralAir', 'Foundation', 'ExterQual', 'ExterCond', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'KitchenQual',
#        'FireplaceQu', 'MSSubClass', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageYrBlt',
#        'GarageArea', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'MiscVal', 'MoSold', 'YrSold', 'Id', 'Alley', 'LotShape',
#        'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition2', 'BldgType', 'HouseStyle',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd',
#        'MasVnrType', 'BsmtFinType2', 'HeatingQC', 'Electrical',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'], dtype=object)

# %%
# which features have been used to build the tree
dtree_model.best_estimator_.named_steps.decisiontreeclassifier
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Feature Importance

# %%
# feature importance for
# tree ...
best_estimator = dtree_model.best_estimator_
path = best_estimator.named_steps["decisiontreeclassifier"]

# # ...and forest:
# best_estimator = forest_model.best_estimator_
# path = best_estimator.named_steps["randomforestclassifier"]

feature_importance = path.feature_importances_
zipper = zip(X_train.columns, feature_importance)
sorted = sorted(zipper, key=lambda x: x[1], reverse=True)
for f, i in sorted:
    print(f"{f}:   {i: .3f}")
# Out:
# Street:    0.490
# MSSubClass:    0.160
# BsmtFinType1:    0.043
# LotArea:    0.031
# LotFrontage:    0.027
# Electrical:    0.025
# FullBath:    0.021
# BsmtQual:    0.019
# BsmtFinSF2:    0.018
# 1stFlrSF:    0.013
# KitchenQual:    0.013
# WoodDeckSF:    0.006
# BsmtFullBath:    0.005
# GarageYrBlt:    0.003
# Fence:    0.002
# TotalBsmtSF:    0.000
# BedroomAbvGr:    0.000
# Fireplaces:    0.000
# PoolArea:    0.000
# GarageCars:    0.000
# ScreenPorch:    0.000
# MSZoning:    0.000
# Condition1:    0.000
# Heating:    0.000
# CentralAir:    0.000
# Foundation:    0.000
# ExterQual:    0.000
# ExterCond:    0.000
# BsmtCond:    0.000
# BsmtExposure:    0.000
# FireplaceQu:    0.000
# OverallQual:    0.000
# OverallCond:    0.000
# YearBuilt:    0.000
# YearRemodAdd:    0.000
# MasVnrArea:    0.000
# BsmtFinSF1:    0.000
# BsmtUnfSF:    0.000
# 2ndFlrSF:    0.000
# LowQualFinSF:    0.000
# GrLivArea:    0.000
# BsmtHalfBath:    0.000
# HalfBath:    0.000
# KitchenAbvGr:    0.000
# TotRmsAbvGrd:    0.000
# GarageArea:    0.000
# OpenPorchSF:    0.000
# EnclosedPorch:    0.000
# 3SsnPorch:    0.000
# MiscVal:    0.000
# MoSold:    0.000
# YrSold:    0.000
# Id:    0.000
# Alley:    0.000
# LotShape:    0.000
# LandContour:    0.000
# Utilities:    0.000
# LotConfig:    0.000
# LandSlope:    0.000
# Neighborhood:    0.000
# Condition2:    0.000
# BldgType:    0.000
# HouseStyle:    0.000
# RoofStyle:    0.000
# RoofMatl:    0.000
# Exterior1st:    0.000
# Exterior2nd:    0.000
# MasVnrType:    0.000
# BsmtFinType2:    0.000
# HeatingQC:    0.000
# Functional:    0.000
# GarageType:    0.000
# GarageFinish:    0.000
# GarageQual:    0.000
# GarageCond:    0.000
# PavedDrive:    0.000
# PoolQC:    0.000
# MiscFeature:    0.000
# SaleType:    0.000
# SaleCondition:    0.000

# %% [markdown]
# # Evaluators (Test Data)

# %%
models = [dtree_model, knn_model, LogReg_model, SVC_model, forest_model]
model_names = ["dtree_model", "knn_model", "LogReg_model", "SVC_model", "forest_model"]

# %% [markdown]
# ## <<< Accuracy, F-Score &al

# %%
from sklearn.metrics import accuracy_score, f1_score, cohen_kappa_score, precision_score, recall_score, roc_auc_score, balanced_accuracy_score

models = [dtree_model, knn_model, LogReg_model, SVC_model, forest_model]
model_names = ["dtree_model", "knn_model", "LogReg_model", "SVC_model", "forest_model"]

eval_dict = {}

for m, n in zip(models, model_names):
    # accuracy
    y_test_pred = m.predict(X_test)
    test_acc = accuracy_score(y_test, y_test_pred)

    # balanced accuracy
    bal_acc = round(balanced_accuracy_score(y_test, y_test_pred), 4)

    # precision
    precision = round(precision_score(y_test, y_test_pred), 4)

    # recall
    recall = round(recall_score(y_test, y_test_pred), 4)

    # f1-score
    f1 = round(f1_score(y_test, y_test_pred), 4)
    f1_micro = round(f1_score(y_test, y_test_pred, average='micro'), 4)
    f1_macro = round(f1_score(y_test, y_test_pred, average='macro'), 4)
    f1_weighted = round(f1_score(y_test, y_test_pred, average='weighted'), 4)

    # Cohen's Kappa Coefficient
    kappa = round(cohen_kappa_score(y_test, y_test_pred), 4)

    # ROC AUC
    roc_auc = round(roc_auc_score(y_test, y_test_pred), 4)

    # AUC-PR



    # Storing results in eval_dict
    eval_dict[n] = {
        "Accuracy": test_acc,
        "Balanced Accuracy": bal_acc,
        "Precision": precision,
        "Recall": recall,
        "F-Score": f1,
        "F1 Micro": f1_micro,
        "F1 Macro": f1_macro,
        "F1 Weighted": f1_weighted,
        "Kappa": kappa,
        "ROC AUC": roc_auc,

    }
    
eval_df = pd.DataFrame(eval_dict)

# metric comment
comments_dict = {
        "Accuracy": "Accuracy on the testing set",
        "Precision": "Proportion of true positive predictions among all positive predictions.  focuses on the accuracy of the positive predictions",
        "Recall": "Proportion of true positive predictions among all actual positives. ability of the classifier to capture ALL the positives",
        "F-Score": "Harmonic mean of precision and recall",
        "Kappa": "Statistic to measure inter-rater agreement",
        "ROC AUC": "Area under the Receiver Operating Characteristic curve"
        }
eval_df['metric comment'] = eval_df.index.map(comments_dict)
pd.set_option('display.max_colwidth', 200)  # set column width for comment

eval_df
# Out:
#                    dtree_model  knn_model  LogReg_model  SVC_model  \
# Accuracy              0.928082   0.952055      0.921233   0.938356
# Balanced Accuracy     0.859000   0.863000      0.884700   0.924400
# Precision             0.744200   0.911800      0.686300   0.730800
# Recall                0.761900   0.738100      0.833300   0.904800
# F-Score               0.752900   0.815800      0.752700   0.808500
# F1 Micro              0.928100   0.952100      0.921200   0.938400
# F1 Macro              0.855400   0.894100      0.852900   0.885900
# F1 Weighted           0.928400   0.949900      0.924300   0.941000
# Kappa                 0.710900   0.788600      0.706400   0.772300
# ROC AUC               0.859000   0.863000      0.884700   0.924400
#
#                    forest_model  \
# Accuracy               0.945205
# Balanced Accuracy      0.839200
# Precision              0.906200
# Recall                 0.690500
# F-Score                0.783800
# F1 Micro               0.945200
# F1 Macro               0.876200
# F1 Weighted            0.942000
# Kappa                  0.753100
# ROC AUC                0.839200
#
#                                                                                                                                  metric comment
# Accuracy                                                                                                            Accuracy on the testing set
# Balanced Accuracy                                                                                                                           NaN
# Precision          Proportion of true positive predictions among all positive predictions.  focuses on the accuracy of the positive predictions
# Recall               Proportion of true positive predictions among all actual positives. ability of the classifier to capture ALL the positives
# F-Score                                                                                                   Harmonic mean of precision and recall
# F1 Micro                                                                                                                                    NaN
# F1 Macro                                                                                                                                    NaN
# F1 Weighted                                                                                                                                 NaN
# Kappa                                                                                                Statistic to measure inter-rater agreement
# ROC AUC                                                                                  Area under the Receiver Operating Characteristic curve

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.DataFrame(eval_dict).T
plt.figure(figsize=(6, 4))
heatmap = sns.heatmap(df.T, annot=True, cmap="Spectral", fmt=".4f", linewidths=0, cbar_kws={"label": "Metric Value"})
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.title('Estimator Comparison')
plt.show()

# %%
model_scores_dict # compare! shouldn't this be identical with Trainin_Accuracy? (or is it the mean and data-subset thing again??)
# Out:
# {'dtree': 0.9169,
#  'knn': 0.9204,
#  'LogReg': 0.9264,
#  'SVC': 0.9426,
#  'forest': 0.9409}

# %% [markdown]
# ## Confusion Matrices

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

num_rows = 2
num_cols = 3
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10))
axes = axes.flatten()

for i, (m, n) in enumerate(zip(models, model_names)):
    ax = axes[i]
    disp = ConfusionMatrixDisplay.from_estimator(m, X_test, y_test, display_labels=['Expensive', 'Not expensive'], ax=ax)
    ax.set_title(f'Confusion Matrix - {n}')

plt.tight_layout()
plt.show()

# %%
eval_df
# Out:
#                    dtree_model  knn_model  LogReg_model  SVC_model  \
# Accuracy              0.928082   0.952055      0.921233   0.938356
# Balanced Accuracy     0.859000   0.863000      0.884700   0.924400
# Precision             0.744200   0.911800      0.686300   0.730800
# Recall                0.761900   0.738100      0.833300   0.904800
# F-Score               0.752900   0.815800      0.752700   0.808500
# F1 Micro              0.928100   0.952100      0.921200   0.938400
# F1 Macro              0.855400   0.894100      0.852900   0.885900
# F1 Weighted           0.928400   0.949900      0.924300   0.941000
# Kappa                 0.710900   0.788600      0.706400   0.772300
# ROC AUC               0.859000   0.863000      0.884700   0.924400
#
#                    forest_model  \
# Accuracy               0.945205
# Balanced Accuracy      0.839200
# Precision              0.906200
# Recall                 0.690500
# F-Score                0.783800
# F1 Micro               0.945200
# F1 Macro               0.876200
# F1 Weighted            0.942000
# Kappa                  0.753100
# ROC AUC                0.839200
#
#                                                                                                                                  metric comment
# Accuracy                                                                                                            Accuracy on the testing set
# Balanced Accuracy                                                                                                                           NaN
# Precision          Proportion of true positive predictions among all positive predictions.  focuses on the accuracy of the positive predictions
# Recall               Proportion of true positive predictions among all actual positives. ability of the classifier to capture ALL the positives
# F-Score                                                                                                   Harmonic mean of precision and recall
# F1 Micro                                                                                                                                    NaN
# F1 Macro                                                                                                                                    NaN
# F1 Weighted                                                                                                                                 NaN
# Kappa                                                                                                Statistic to measure inter-rater agreement
# ROC AUC                                                                                  Area under the Receiver Operating Characteristic curve

# %% [markdown]
# ## Plotting Decision Tree

# %%
# we also need the column names for the features that have been passed to the decision tree
columns_after_preprocessing = (
    dtree_model.best_estimator_.named_steps.columntransformer.named_transformers_["pipeline-1"].get_feature_names_out().tolist()
    +
    dtree_model.best_estimator_.named_steps.columntransformer.named_transformers_["pipeline-2"].get_feature_names_out().tolist()
    )
# columns_after_preprocessing

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(64, 32))

plot_tree(
     dtree_model.best_estimator_['decisiontreeclassifier'],
     filled=True,
     rounded=True,
     class_names=['Not Expensive','Expensive'],
     feature_names=columns_after_preprocessing
     );

# %% [markdown]
# # Resulting Model (Real Data)

# %%
# libraries and settings
from sklearn.externals import joblib

# import real_data (and model?)
real_data = 
# model= joblib.load('model.pkl')  # Load the model from the file

# data prep
y_test = real_data.pop(y)
X_test = real_data

# upper reach

# downstream

svc + recall + confusion matrix with obenrechts=0
    'svc__C': [5, 10, 20, 50], # C needs to be > 0                     # 'svc__C': [0.5, 1, 10, 100, 1000], # C values must be > 0
    'svc__kernel': ['rbf'],                                            # 'svc__kernel': ['linear', 'rbf', 'poly'],
    'svc__gamma': ['scale', 'auto', 0.00001, 0.0001, 0.01],             # 'svc__gamma': ['scale', 'auto', 0.0001, 0.001, 0.01, 0.1, 1, 10, 100]

# give results
model_name_kko124 = model
joblib.dump(model_name_kko124, 'model_name_kko124.pkl')  # Save the model to a file
# Out:
#   Cell In[49], line 5
#     real_data =
#                 ^
# SyntaxError: invalid syntax
